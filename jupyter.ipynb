# %%
import pandas as pd
Agriculture = pd.read_csv('Agriculture')
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('bmh')
sns.relplot(x='Year', y='emissions_quantity', kind='scatter', row='sector',  col='sub-sector', data=Agriculture, hue='iso3_country', alpha=0.8)
plt.show()
